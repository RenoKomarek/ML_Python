# %%
import pandas as pd
import numpy as np

train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

train_data.head()
# Out:
#       id   age  hypertension  heart_disease  avg_glucose_level   bmi  \
# 0  52709  30.0             0              0              63.60  33.3
# 1  72295  75.0             1              0             215.17  48.0
# 2  26451  15.0             0              0             135.22  19.0
# 3  65210  47.0             0              0              64.89  28.2
# 4  69299  49.0             0              0             222.34  28.8
#
#    gender_Female  gender_Male  gender_Other  ever_married_No  ...  \
# 0          False         True         False             True  ...
# 1           True        False         False            False  ...
# 2          False         True         False             True  ...
# 3          False         True         False            False  ...
# 4          False         True         False            False  ...
#
#    work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                   False               True                    False
# 1                   False              False                     True
# 2                   False               True                    False
# 3                   False              False                     True
# 4                   False              False                     True
#
#    work_type_children  Residence_type_Rural  Residence_type_Urban  \
# 0               False                  True                 False
# 1               False                  True                 False
# 2               False                  True                 False
# 3               False                 False                  True
# 4               False                  True                 False
#
#    smoking_status_formerly smoked  smoking_status_never smoked  \
# 0                           False                        False
# 1                           False                         True
# 2                           False                         True
# 3                           False                         True
# 4                            True                        False
#
#    smoking_status_smokes  stroke
# 0                   True       0
# 1                  False       0
# 2                  False       0
# 3                  False       0
# 4                  False       0
#
# [5 rows x 22 columns]

# %%
train_data_cleaned = train_data.drop(columns=['id', 'ever_married_No', 'Residence_type_Rural'])

# Filtering out unrealistic BMI and glucose values
train_data_cleaned = train_data_cleaned[
    (train_data_cleaned['bmi'] >= 10) & (train_data_cleaned['bmi'] <= 50) &
    (train_data_cleaned['avg_glucose_level'] >= 55) & (train_data_cleaned['avg_glucose_level'] <= 250)
]

# Display the cleaned dataset
train_data_cleaned.head()
# Out:
#     age  hypertension  heart_disease  avg_glucose_level   bmi  gender_Female  \
# 0  30.0             0              0              63.60  33.3          False
# 1  75.0             1              0             215.17  48.0           True
# 2  15.0             0              0             135.22  19.0          False
# 3  47.0             0              0              64.89  28.2          False
# 4  49.0             0              0             222.34  28.8          False
#
#    gender_Male  gender_Other  ever_married_Yes  work_type_Govt_job  \
# 0         True         False             False               False
# 1        False         False              True               False
# 2         True         False             False               False
# 3         True         False              True               False
# 4         True         False              True               False
#
#    work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                   False               True                    False
# 1                   False              False                     True
# 2                   False               True                    False
# 3                   False              False                     True
# 4                   False              False                     True
#
#    work_type_children  Residence_type_Urban  smoking_status_formerly smoked  \
# 0               False                 False                           False
# 1               False                 False                           False
# 2               False                 False                           False
# 3               False                  True                           False
# 4               False                 False                            True
#
#    smoking_status_never smoked  smoking_status_smokes  stroke
# 0                        False                   True       0
# 1                         True                  False       0
# 2                         True                  False       0
# 3                         True                  False       0
# 4                        False                  False       0

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV




# Definieer de hyperparameter-ruimte
param_grid = {
    'max_depth': [3, 5, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'criterion': ['gini', 'entropy']
}

# Instantieer een DecisionTreeClassifier
model = DecisionTreeClassifier()

# GridSearchCV gebruiken om de beste hyperparameters te vinden
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='f1')
grid_search.fit(X, y)

# Print de beste parameters en score
print("Beste hyperparameters:", grid_search.best_params_)
print("Beste score:", grid_search.best_score_)
